# %%
import torch
import torch.distributed.rpc as rpc

print(f"PyTorch Version: {torch.__version__}")
print(f"RPC Available: {rpc.is_available()}")
# On Windows, this should return True if the backend compiled correctly
# Out:
# PyTorch Version: 2.10.0+cpu
# RPC Available: False
